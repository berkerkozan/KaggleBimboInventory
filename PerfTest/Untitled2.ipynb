# %%
import pickle
import xgboost as xgb
import pandas as pd
import numpy as np
from sklearn.cross_validation import KFold, train_test_split
from sklearn.metrics import confusion_matrix, mean_squared_error
from sklearn.grid_search import GridSearchCV
from sklearn.datasets import load_iris, load_digits, load_boston
# %matplotlib inline
import seaborn as sns
from sklearn.metrics import r2_score, mean_squared_error, make_scorer
from collections import OrderedDict
import gc
from sklearn import datasets, linear_model,preprocessing
from IPython.display import display, HTML
import time
import nltk.corpus
from nltk.stem.snowball import SnowballStemmer

# %%
#take 1 CSV, then split it to 3..
class FeatureEngineering:

    def __init__(self, ValidationStart, ValidationEnd, trainHdfPath, trainHdfFile, testHdfPath1, testHdfPath2, testHdfFile, 
                 testTypes, trainTypes, trainCsvPath, testCsvPath, maxLag=0):
        self.ValidationStart = ValidationStart
        self.ValidationEnd = ValidationEnd
        self.maxLag = maxLag
        self.trainHdfPath = trainHdfPath
        self.trainHdfFile = trainHdfFile
        self.testHdfPath1 = testHdfPath1
        self.testHdfPath2 = testHdfPath2
        self.testHdfFile = testHdfFile
        self.testTypes = testTypes
        self.trainTypes = trainTypes
        self.trainCsvPath = trainCsvPath
        self.testCsvPath = testCsvPath
        
    @staticmethod
    def __printDataFrameBasics__(data):
        display(data.head(2))
        #print data.dtypes
        gc.collect()
        print(data.info(memory_usage=True))
        
    @staticmethod    
    def changeIndexTypeToLowerMemory(data):
        ##########
        #This is very critical, i accept max number is 2^32. Also, if don't do that, memory gets so much higher..
        ##########
        #data.reset_index(inplace=True)
        #data.drop("index",axis=1, inplace=True)
        #data.index = data.index.astype('uint32')
        gc.collect()
        
    def ReadHdf(self, trainOrTestOrBoth):
        '''Reads and holds Df in object memory'''            
        if trainOrTestOrBoth == 'train' or trainOrTestOrBoth=='both':
            self.train = pd.read_hdf(self.trainHdfPath,self.trainHdfFile)
            FeatureEngineering.changeIndexTypeToLowerMemory(self.train)
            FeatureEngineering.__printDataFrameBasics__(self.train)
            
        if trainOrTestOrBoth == 'test' or trainOrTestOrBoth=='both':
            self.test1 = pd.read_hdf(self.testHdfPath1,self.testHdfFile)
            self.test2 = pd.read_hdf(self.testHdfPath2,self.testHdfFile)
            FeatureEngineering.changeIndexTypeToLowerMemory(self.test1)
            FeatureEngineering.changeIndexTypeToLowerMemory(self.test2)
            FeatureEngineering.__printDataFrameBasics__(self.test1)
            FeatureEngineering.__printDataFrameBasics__(self.test2)
        
    def ReadCsv(self, trainOrTestOrBoth):
        '''Reads and holds Df in memory'''
        if trainOrTestOrBoth == 'train' or trainOrTestOrBoth == 'both':
            self.train = pd.read_csv(self.trainCsvPath, usecols=self.trainTypes.keys(), dtype=self.trainTypes)
            FeatureEngineering.changeIndexTypeToLowerMemory(self.train)
            FeatureEngineering.__printDataFrameBasics__(self.train)
        if trainOrTestOrBoth == 'test' or trainOrTestOrBoth=='both':
            tempTest = pd.read_csv(self.testCsvPath, usecols=self.testTypes.keys(), dtype=self.testTypes)
            self.test1 = tempTest.loc[tempTest.Semana.values == self.ValidationStart]
            self.test2 = tempTest.loc[tempTest.Semana.values == self.ValidationEnd]
            del tempTest
            FeatureEngineering.changeIndexTypeToLowerMemory(self.test1)
            FeatureEngineering.changeIndexTypeToLowerMemory(self.test2)
            FeatureEngineering.__printDataFrameBasics__(self.test1)
            FeatureEngineering.__printDataFrameBasics__(self.test2)
            
    @staticmethod
    def ConvertCsvToHdf(csvPath, HdfPath, HdfName, ColumnTypeDict ):
        tempDf = pd.read_csv(csvPath, usecols=ColumnTypeDict.keys(), dtype=ColumnTypeDict,index=False)
        tempDf.to_hdf(HdfPath, HdfName, format='t')
        del tempDf
        gc.collect()
        print "ConvertCsvToHdf is done.."

    def Preprocess(self, trainOrTestOrBoth, columnFunctionTypeList):
        '''columnFunctionTypeList = [ ['C1',Func1,Type], ['C2',Func2,Type],..    ]'''
        for column, func, localType in columnFunctionTypeList:
            if trainOrTestOrBoth == 'train' or trainOrTestOrBoth =='both':
                self.train.loc[:,column] =  np.apply_along_axis(func,0,FE.train[column].values).astype(localType)
                #np.apply_along_axis(lambda x: x+1,0,FE.train["Semana"]).astype("int32")
            if trainOrTestOrBoth == 'test' or trainOrTestOrBoth == 'both':
                self.test1.loc[:,column] =  np.apply_along_axis(func,0,FE.test1[column].values).astype(localType)
                self.test2.loc[:,column] =  np.apply_along_axis(func,0,FE.test2[column].values).astype(localType)
        gc.collect()
        
    def SaveDataFrameToHdf(self,trainOrTestOrBoth):
        if trainOrTestOrBoth == 'train' or trainOrTestOrBoth=='both':
            self.train.to_hdf(self.trainHdfPath, self.trainHdfFile, format='t', index="False")
        if trainOrTestOrBoth == 'test' or trainOrTestOrBoth=='both':
            self.test1.to_hdf(self.testHdfPath1, self.testHdfFile, format='t', index="False")
            self.test2.to_hdf(self.testHdfPath2, self.testHdfFile, format='t', index="False")
        
    def AddDemandaGeneralMean(self,trainOrTestOrBoth): 
        #self.train.loc[:,"DemandaGeneralMean"] = self.train["Demanda_uni_equil"].loc[
         #   self.train.loc[:,'Semana'] < 10].mean().astype("float32")
            
        meanOfDemanda = self.train["Demanda_uni_equil"].values.mean().astype("float32")
        
        if trainOrTestOrBoth == 'train' or trainOrTestOrBoth=='both':
            self.train.loc[:,"DemandaGeneralMean"] = meanOfDemanda
        if trainOrTestOrBoth == 'test' or trainOrTestOrBoth=='both':
            self.test1.loc[:,"DemandaGeneralMean"] = meanOfDemanda
            self.test2.loc[:,"DemandaGeneralMean"] = meanOfDemanda
        
        #self.train.loc[:,"DemandaGeneralMean"] = self.train["Demanda_uni_equil"].values[
        #(self.train.loc[:,'Semana'].values < self.ValidationStart).values].mean().astype("float32")
        gc.collect()
        
    '''ConfigElements(0,[ ("A",["Semana","Agencia_ID"],["count","count"]),'''
    def AddConfigurableFeaturesToTrain(self, config):
        if config.lag > self.maxLag:
            self.maxLag = config.lag
        
        tempData = self.train[self.train['Semana'].values <= (self.ValidationEnd - config.lag)]
        #display(tempData)
        if(config.lag != 0):
            tempData.loc[:,'Semana'] = tempData['Semana'].values + config.lag
        #display(tempData)
        
        #Means iterative.. eliminate as long as np.nan exists..If there is already one, don't create, use the existing
        if config.targetVariable != "" and  config.targetVariable not in self.train.columns:
            self.train.loc[:,config.targetVariable] = np.nan
            self.test1.loc[:,config.targetVariable] = np.nan
            
            if config.lag != 1:
                self.test2.loc[:,config.targetVariable] = np.nan
        
        for name,groups,aggregate in config.nameAndGroups:
            if name not in self.train.columns:
                print "{} is not in columns..".format(name)            
                
                groupedDataframe = tempData[groups+['Demanda_uni_equil']].copy().groupby(groups).agg(aggregate[0])
                gc.collect()
                #groupedDataframe.columns = groupedDataframe.columns.droplevel(0)
                groupedDataframe.columns = [name]
                
                #This is means of the counts of the semana-columns tuples!..!!!
                #If no lag and mean, mean of the columns without semana!!..
                #If there is lag and count, count of the columns x weeks before
                #If there is lag and mean, mean of the columns x weeks before
                #if(config.lag == 0 and aggregate == "count"):
                if(len(aggregate)>1):
                    groupedDataframe.reset_index(inplace=True)
                    groupedDataframe.drop("Semana",axis=1, inplace=True)
                    groups = groups[1:]
                    groupedDataframe = groupedDataframe.groupby(groups).agg(aggregate[1])
                    groupedDataframe.columns = [name]
                    gc.collect()
                
                display(groupedDataframe)
                self.train = self.train.merge( groupedDataframe, left_on=groups,
                    right_index=True, how='left', sort=False,copy=False)
                gc.collect()
                self.test1 = self.test1.merge( groupedDataframe, left_on=groups,
                    right_index=True, how='left', sort=False,copy=False)
                gc.collect()
                if config.lag != 1:
                    self.test2 = self.test2.merge( groupedDataframe, left_on=groups,
                        right_index=True, how='left', sort=False,copy=False)
                
                del groupedDataframe
                gc.collect()
            else:
                print "{} is in columns..".format(name)
            
            display(self.train)
            display(self.test1)
            display(self.test2)
            
            #Means iterative..!!!!!
            if config.targetVariable != "":
                self.train.loc[pd.isnull(self.train[config.targetVariable].values), 
                    config.targetVariable] = self.train.loc[pd.isnull(self.train[config.targetVariable].values)
                    , name].values
                self.test1.loc[pd.isnull(self.test1[config.targetVariable].values), 
                    config.targetVariable] = self.test1.loc[pd.isnull(self.test1[config.targetVariable].values),
                    name].values
                if config.lag != 1:
                    self.test2.loc[pd.isnull(self.test2[config.targetVariable].values), 
                        config.targetVariable] = self.test2.loc[pd.isnull(self.test2[config.targetVariable].values)
                        , name].values
                    
                count = self.test1[config.targetVariable].isnull().sum()
                print "Count of missing numbers after {} in validation part 1 in column {} is {}".format(name, 
                    config.targetVariable,str(count))
                if config.lag != 1:
                    count = self.test2.loc[:,config.targetVariable].isnull().sum()
                    print "Count of missing numbers after {} in validation part 2 in column {} is {}".format(name, 
                        config.targetVariable,str(count))
                
                
                #display(self.train)
                #If column is already in Dataframe and we want to fill target variable, this deletes columns!!!
                if(config.deleteColumns):
                    self.train.drop(name, axis=1, inplace=True)
                    self.test1.drop(name, axis=1, inplace=True)
                    if config.lag != 1:
                        self.test2.drop(name, axis=1, inplace=True)
                gc.collect()
                #Only in tesst
                #if count == 0:
                 #   break
        del tempData
        display(self.train)   
        display(self.test1)   
        display(self.test2)
        gc.collect()
        return 
    
    def DeleteLaggedWeeksFromTrain(self):
        self.train = self.train[self.train['Semana'].values >= (3 + self.maxLag)]
        gc.collect()
        display(self.train.head(2))
        
    def ReadFirstNRowsOfACsv(self, nrows, trainOrTestOrBoth) :
        if trainOrTestOrBoth == 'train' or trainOrTestOrBoth=='both':
            self.train = pd.read_csv(self.trainCsvPath, usecols=self.trainTypes.keys(), dtype=self.trainTypes, nrows = nrows)
            FeatureEngineering.changeIndexTypeToLowerMemory(self.train)
            FeatureEngineering.__printDataFrameBasics__(self.train)
        if trainOrTestOrBoth == 'test' or trainOrTestOrBoth=='both':
            tempTest = pd.read_csv(self.testCsvPath, usecols=self.testTypes.keys(), dtype=self.testTypes, nrows = nrows*2)
            self.test1 = tempTest.loc[tempTest.Semana == self.ValidationStart]
            self.test2 = tempTest.loc[tempTest.Semana == self.ValidationEnd]
            del tempTest
            FeatureEngineering.changeIndexTypeToLowerMemory(self.test1)
            FeatureEngineering.changeIndexTypeToLowerMemory(self.test2)
            FeatureEngineering.__printDataFrameBasics__(self.test1)
            FeatureEngineering.__printDataFrameBasics__(self.test2)
    
    #Use when concatanating train and validation before predict test for example..
    def AppendTestToTrain(self,deleteTest = True):
        self.train = self.train.append(self.test1,ignore_index=True)
        gc.collect()
        if(deleteTest):
            del self.test1
            gc.collect()
        try:
            self.train = self.train.append(self.test2,ignore_index=True)
            gc.collect()
            if(deleteTest):
                del self.test2
                gc.collect()
        except:
            pass
        #BAD PERFORMANCE!!
    #Split train data to train and test1 and test2 (validation)
    #def SplitTrainToTestUsingValidationStart(self):
     #   boolCondition = self.train.Semana == self.ValidationStart
      #  self.test1 = self.train.loc[boolCondition]
       # self.train.drop((self.train.loc[boolCondition].index), axis=0,inplace=True)
        
       # boolCondition = self.train.Semana == self.ValidationEnd
       # self.test2 = self.train.loc[boolCondition]
       # self.train.drop((self.train.loc[boolCondition].index), axis=0,inplace=True)
      #  del boolCondition
      #  gc.collect()
    
    #Reaches 3x memory from train, because of test1, test2 and train itself at the end.. GC fixed in the end..
    def SplitTrainToTestUsingValidationStart(self):
        boolCondition = self.train.Semana.values == self.ValidationStart
        self.test1 = self.train[boolCondition]
        boolCondition = self.train.Semana.values == self.ValidationEnd
        self.test2 = self.train[boolCondition]
        FE.train = FE.train[ FE.train.Semana.values < FE.ValidationStart ]
        del boolCondition
        gc.collect()
        
    def XgboostPredictAndSee(self, Test1OrTest2):
        self.train_y = self.train["Demanda_uni_equil"].copy()
        self.train.drop("Demanda_uni_equil",axis=1, inplace=True)

# %%
parameterDict =       {"ValidationStart":8, 
 "ValidationEnd":9,
   "maxLag":3,
    "trainHdfPath":'../../input/train.h5',
    "trainHdfFile":"train",
    "testHdfPath1":"../../input/test1.h5",
    "testHdfPath2":"../../input/test2.h5",
    "testHdfFile":"test", 
    "trainTypes" : {'Semana':np.uint8, 'Agencia_ID':np.uint16, 'Canal_ID':np.uint8,'Ruta_SAK':np.uint16, 
        'Cliente_ID':np.uint32, 'Producto_ID':np.uint16,'Venta_uni_hoy':np.uint16, 'Venta_hoy':np.float32,
                    'Dev_uni_proxima': np.uint32, 'Dev_proxima':np.float32,'Demanda_uni_equil':np.uint32}, 
    "testTypes" : {'id':np.uint32,'Semana':np.uint8, 'Agencia_ID':np.uint16, 'Canal_ID':np.uint8,'Ruta_SAK':np.uint16,
        'Cliente_ID':np.uint32, 'Producto_ID':np.uint16},
    "trainCsvPath":'../../input/train.csv'   ,
    "testCsvPath":'../../input/test.csv'}

FE = FeatureEngineering(**parameterDict)
print FE.__dict__
# Out:
# {'trainCsvPath': '../../input/train.csv', 'maxLag': 3, 'testTypes': {'Cliente_ID': <type 'numpy.uint32'>, 'Ruta_SAK': <type 'numpy.uint16'>, 'Canal_ID': <type 'numpy.uint8'>, 'Producto_ID': <type 'numpy.uint16'>, 'Agencia_ID': <type 'numpy.uint16'>, 'Semana': <type 'numpy.uint8'>, 'id': <type 'numpy.uint32'>}, 'testHdfFile': 'test', 'trainTypes': {'Dev_proxima': <type 'numpy.float32'>, 'Venta_uni_hoy': <type 'numpy.uint16'>, 'Cliente_ID': <type 'numpy.uint32'>, 'Demanda_uni_equil': <type 'numpy.uint32'>, 'Ruta_SAK': <type 'numpy.uint16'>, 'Canal_ID': <type 'numpy.uint8'>, 'Venta_hoy': <type 'numpy.float32'>, 'Producto_ID': <type 'numpy.uint16'>, 'Agencia_ID': <type 'numpy.uint16'>, 'Dev_uni_proxima': <type 'numpy.uint32'>, 'Semana': <type 'numpy.uint8'>}, 'testHdfPath1': '../../input/test1.h5', 'ValidationEnd': 9, 'testHdfPath2': '../../input/test2.h5', 'testCsvPath': '../../input/test.csv', 'ValidationStart': 8, 'trainHdfFile': 'train', 'trainHdfPath': '../../input/train.h5'}

# %%
FE.ReadHdf('both')
# Out:
#    Semana  Agencia_ID  Canal_ID  Ruta_SAK  Cliente_ID  Producto_ID  \
# 0       3        1110         7      3301       15766         1212
# 1       3        1110         7      3301       15766         1216
#
#    Venta_uni_hoy  Venta_hoy  Dev_uni_proxima  Dev_proxima  ...   Town_ID  \
# 0              3  25.139999                0          0.0  ...      2008
# 1              4  33.520000                0          0.0  ...      2008
#
#   State_ID  DemandaGeneralMean  Lag0  Lag0Averaged  Demanda_uni_equilLogged  \
# 0       16            7.346896  12.0           2.0                 1.386294
# 1       16            7.346896  12.0           2.0                 1.609438
#
#    Lag0AveragedLogged  Lag1  Lag2  Lag3
# 0            1.098612   NaN   NaN   NaN
# 1            1.098612   NaN   NaN   NaN
#
# [2 rows x 26 columns]
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 52449630 entries, 0 to 52449629
# Data columns (total 26 columns):
# Semana                                          uint8
# Agencia_ID                                      uint16
# Canal_ID                                        uint8
# Ruta_SAK                                        uint16
# Cliente_ID                                      uint32
# Producto_ID                                     uint16
# Venta_uni_hoy                                   uint16
# Venta_hoy                                       float32
# Dev_uni_proxima                                 uint32
# Dev_proxima                                     float32
# Demanda_uni_equil                               uint32
# DemandaNotEqualTheDifferenceOfVentaUniAndDev    bool
# weight                                          uint16
# pieces                                          uint8
# Prod_name_ID                                    uint16
# Brand_ID                                        uint8
# Town_ID                                         uint16
# State_ID                                        uint8
# DemandaGeneralMean                              float32
# Lag0                                            float64
# Lag0Averaged                                    float64
# Demanda_uni_equilLogged                         float64
# Lag0AveragedLogged                              float64
# Lag1                                            float64
# Lag2                                            float64
# Lag3                                            float64
# dtypes: bool(1), float32(3), float64(7), uint16(7), uint32(3), uint8(5)
# memory usage: 5.3 GB
# None
#           Semana  Agencia_ID  Canal_ID  Ruta_SAK  Cliente_ID  Producto_ID  \
# 52449630       8        1110         7      3301       15766         1212
# 52449631       8        1110         7      3301       15766         1216
#
#           Venta_uni_hoy  Venta_hoy  Dev_uni_proxima  Dev_proxima  ...   \
# 52449630              4  33.520000                0          0.0  ...
# 52449631              5  41.900002                0          0.0  ...
#
#           Town_ID State_ID  DemandaGeneralMean  Lag0  Lag0Averaged  \
# 52449630     2008       16            7.346896  12.0           2.0
# 52449631     2008       16            7.346896  12.0           2.0
#
#           Demanda_uni_equilLogged  Lag0AveragedLogged      Lag1      Lag2  \
# 52449630                 1.609438            1.098612  5.864407  5.931034
# 52449631                 1.791759            1.098612  2.000000  1.000000
#
#           Lag3
# 52449630   5.0
# 52449631   3.0
#
# [2 rows x 26 columns]
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10193576 entries, 52449630 to 62643205
# Data columns (total 26 columns):
# Semana                                          uint8
# Agencia_ID                                      uint16
# Canal_ID                                        uint8
# Ruta_SAK                                        uint16
# Cliente_ID                                      uint32
# Producto_ID                                     uint16
# Venta_uni_hoy                                   uint16
# Venta_hoy                                       float32
# Dev_uni_proxima                                 uint32
# Dev_proxima                                     float32
# Demanda_uni_equil                               uint32
# DemandaNotEqualTheDifferenceOfVentaUniAndDev    bool
# weight                                          uint16
# pieces                                          uint8
# Prod_name_ID                                    uint16
# Brand_ID                                        uint8
# Town_ID                                         uint16
# State_ID                                        uint8
# DemandaGeneralMean                              float32
# Lag0                                            float64
# Lag0Averaged                                    float64
# Demanda_uni_equilLogged                         float64
# Lag0AveragedLogged                              float64
# Lag1                                            float64
# Lag2                                            float64
# Lag3                                            float64
# dtypes: bool(1), float32(3), float64(7), uint16(7), uint32(3), uint8(5)
# memory usage: 1.0 GB
# None
#           Semana  Agencia_ID  Canal_ID  Ruta_SAK  Cliente_ID  Producto_ID  \
# 62643206       9        1110         7      3301       15766         1212
# 62643207       9        1110         7      3301       15766         1238
#
#           Venta_uni_hoy  Venta_hoy  Dev_uni_proxima  Dev_proxima    ...     \
# 62643206              1       8.38                0          0.0    ...
# 62643207              2      19.66                0          0.0    ...
#
#           Brand_ID Town_ID  State_ID  DemandaGeneralMean  Lag0  Lag0Averaged  \
# 62643206         4    2008        16            7.346896  12.0           2.0
# 62643207         4    2008        16            7.346896  12.0           2.0
#
#           Demanda_uni_equilLogged  Lag0AveragedLogged      Lag2      Lag3
# 62643206                 0.693147            1.098612  5.864407  5.931034
# 62643207                 1.098612            1.098612  2.000000  2.000000
#
# [2 rows x 25 columns]
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10200437 entries, 62643206 to 72843642
# Data columns (total 25 columns):
# Semana                                          uint8
# Agencia_ID                                      uint16
# Canal_ID                                        uint8
# Ruta_SAK                                        uint16
# Cliente_ID                                      uint32
# Producto_ID                                     uint16
# Venta_uni_hoy                                   uint16
# Venta_hoy                                       float32
# Dev_uni_proxima                                 uint32
# Dev_proxima                                     float32
# Demanda_uni_equil                               uint32
# DemandaNotEqualTheDifferenceOfVentaUniAndDev    bool
# weight                                          uint16
# pieces                                          uint8
# Prod_name_ID                                    uint16
# Brand_ID                                        uint8
# Town_ID                                         uint16
# State_ID                                        uint8
# DemandaGeneralMean                              float32
# Lag0                                            float64
# Lag0Averaged                                    float64
# Demanda_uni_equilLogged                         float64
# Lag0AveragedLogged                              float64
# Lag2                                            float64
# Lag3                                            float64
# dtypes: bool(1), float32(3), float64(6), uint16(7), uint32(3), uint8(5)
# memory usage: 972.8 MB
# None

# %%
FE.DeleteLaggedWeeksFromTrain()
X_train = FE.train[["Lag0AveragedLogged","Lag1","Lag2","Lag3","weight","pieces"]]
X_test = FE.test1[["Lag0AveragedLogged","Lag1","Lag2","Lag3","weight","pieces"]]
y_train = FE.train["Demanda_uni_equilLogged"]
y_test = FE.test1["Demanda_uni_equilLogged"]
gc.collect()
# Out:
#           Semana  Agencia_ID  Canal_ID  Ruta_SAK  Cliente_ID  Producto_ID  \
# 32263831       6        1110         7      3301       15766         1216
# 32263832       6        1110         7      3301       15766         1238
#
#           Venta_uni_hoy  Venta_hoy  Dev_uni_proxima  Dev_proxima  ...   \
# 32263831              1       8.38                0          0.0  ...
# 32263832              2      19.66                0          0.0  ...
#
#           Town_ID State_ID  DemandaGeneralMean  Lag0  Lag0Averaged  \
# 32263831     2008       16            7.346896  12.0           2.0
# 32263832     2008       16            7.346896  12.0           2.0
#
#           Demanda_uni_equilLogged  Lag0AveragedLogged  Lag1  Lag2  Lag3
# 32263831                 0.693147            1.098612   3.0   2.0   4.0
# 32263832                 1.098612            1.098612   1.0   3.0   4.0
#
# [2 rows x 26 columns]
# 290

# %%
def GiveBestParameterWithoutCV(defaultParams, testParams, X_train, X_test, Y_train, Y_test, fitParams):
    xgb_model = xgb.XGBRegressor(**defaultParams) 
    
    minRmse = 10000
    minRmseParameter = 10000
    bestIteration = 1000
        
    for key,values in testParams:
        minRmseParameter = xgb_model.get_xgb_params()[key]
        
        for value in values:
            
            xgb_model.set_params(**{key:value})
            xgb_model.fit(X_train,Y_train, eval_set=[(X_train, Y_train),(X_test, Y_test)],
                  **fitParams)
            if xgb_model.best_score < minRmse:
                minRmse = xgb_model.best_score
                minRmseParameter = value
                bestIteration = xgb_model.best_iteration
                
        xgb_model.set_params(**{key:minRmseParameter})
        print "Parameters are finished for {}. Best Iteration is {}".format(key, bestIteration)
        print "Minimum Rmse : {}, optimum parameter is {} between {}".format(minRmse, minRmseParameter, values)
    gc.collect()

# %%
defaultParams = {"max_depth":10, "subsample":1., "min_child_weight":5, "colsample_bytree":0.4, "missing":np.nan
                ,"n_estimators":300, "learning_rate":0.1}
testParams = [("max_depth",[12,8,6,14]), ("subsample",[0.9,0.8,0.6]), ("min_child_weight",[1,3,7]),
                  ("colsample_bytree",[0.3,0.5,0.6, 0.8,1]), ("learning_rate",[0.05])]
fitParams = {"verbose":1, "early_stopping_rounds": 10}

GiveBestParameterWithoutCV(defaultParams,testParams, X_train, X_test, y_train, y_test, fitParams )
# Out:
# [0]	validation_0-rmse:1.27064	validation_1-rmse:1.27065
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 10 rounds.
# [1]	validation_0-rmse:1.15527	validation_1-rmse:1.15837
# [2]	validation_0-rmse:1.05345	validation_1-rmse:1.06033
# [3]	validation_0-rmse:0.967846	validation_1-rmse:0.97587
# [4]	validation_0-rmse:0.886167	validation_1-rmse:0.899339
# [5]	validation_0-rmse:0.814787	validation_1-rmse:0.833665
# [6]	validation_0-rmse:0.755924	validation_1-rmse:0.777225
# [7]	validation_0-rmse:0.703402	validation_1-rmse:0.726887
# [8]	validation_0-rmse:0.653241	validation_1-rmse:0.684576
# [9]	validation_0-rmse:0.614181	validation_1-rmse:0.649052
# [10]	validation_0-rmse:0.579789	validation_1-rmse:0.618324
# [11]	validation_0-rmse:0.550357	validation_1-rmse:0.592457
# [12]	validation_0-rmse:0.520938	validation_1-rmse:0.571888
# [13]	validation_0-rmse:0.502385	validation_1-rmse:0.55661
# [14]	validation_0-rmse:0.483902	validation_1-rmse:0.541716
# [15]	validation_0-rmse:0.463968	validation_1-rmse:0.53135
# [16]	validation_0-rmse:0.450659	validation_1-rmse:0.520967
# [17]	validation_0-rmse:0.436246	validation_1-rmse:0.514916
# [18]	validation_0-rmse:0.428437	validation_1-rmse:0.509586
# [19]	validation_0-rmse:0.420712	validation_1-rmse:0.504264
# [20]	validation_0-rmse:0.414176	validation_1-rmse:0.499708
# [21]	validation_0-rmse:0.408779	validation_1-rmse:0.496273
# [22]	validation_0-rmse:0.404372	validation_1-rmse:0.493584
# [23]	validation_0-rmse:0.400654	validation_1-rmse:0.49145
# [24]	validation_0-rmse:0.397589	validation_1-rmse:0.489539
# [25]	validation_0-rmse:0.392979	validation_1-rmse:0.489082
# [26]	validation_0-rmse:0.391044	validation_1-rmse:0.488125
# [27]	validation_0-rmse:0.389333	validation_1-rmse:0.48752
# [28]	validation_0-rmse:0.385064	validation_1-rmse:0.48914
# [29]	validation_0-rmse:0.383969	validation_1-rmse:0.488782
# [30]	validation_0-rmse:0.383079	validation_1-rmse:0.488539
# [31]	validation_0-rmse:0.382287	validation_1-rmse:0.48837
# [32]	validation_0-rmse:0.381698	validation_1-rmse:0.488285
# [33]	validation_0-rmse:0.378533	validation_1-rmse:0.491693
# [34]	validation_0-rmse:0.378151	validation_1-rmse:0.4917
# [35]	validation_0-rmse:0.377828	validation_1-rmse:0.491782
# [36]	validation_0-rmse:0.37657	validation_1-rmse:0.492708
# [37]	validation_0-rmse:0.375548	validation_1-rmse:0.493627
# Stopping. Best iteration:
# [27]	validation_0-rmse:0.389333	validation_1-rmse:0.48752
#
# [0]	validation_0-rmse:1.27093	validation_1-rmse:1.27165
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 10 rounds.
# [1]	validation_0-rmse:1.15583	validation_1-rmse:1.16005
# [2]	validation_0-rmse:1.05427	validation_1-rmse:1.06212
# [3]	validation_0-rmse:0.968864	validation_1-rmse:0.977615
# [4]	validation_0-rmse:0.887342	validation_1-rmse:0.901137
# [5]	validation_0-rmse:0.81619	validation_1-rmse:0.835418
# [6]	validation_0-rmse:0.75745	validation_1-rmse:0.778833
# [7]	validation_0-rmse:0.704973	validation_1-rmse:0.72835
# [8]	validation_0-rmse:0.654943	validation_1-rmse:0.685714
# [9]	validation_0-rmse:0.616014	validation_1-rmse:0.64994
# [10]	validation_0-rmse:0.581707	validation_1-rmse:0.619049
# [11]	validation_0-rmse:0.552355	validation_1-rmse:0.592991
# [12]	validation_0-rmse:0.523115	validation_1-rmse:0.571581
# [13]	validation_0-rmse:0.504676	validation_1-rmse:0.556075
# [14]	validation_0-rmse:0.486332	validation_1-rmse:0.541012
# [15]	validation_0-rmse:0.466622	validation_1-rmse:0.52957
# [16]	validation_0-rmse:0.453341	validation_1-rmse:0.518901
# [17]	validation_0-rmse:0.439018	validation_1-rmse:0.512146
# [18]	validation_0-rmse:0.431235	validation_1-rmse:0.506576
# [19]	validation_0-rmse:0.423555	validation_1-rmse:0.501042
# [20]	validation_0-rmse:0.41705	validation_1-rmse:0.496235
# [21]	validation_0-rmse:0.411715	validation_1-rmse:0.492671
# [22]	validation_0-rmse:0.407302	validation_1-rmse:0.489787
# [23]	validation_0-rmse:0.403597	validation_1-rmse:0.487443
# [24]	validation_0-rmse:0.400546	validation_1-rmse:0.485491
# [25]	validation_0-rmse:0.395927	validation_1-rmse:0.484777
# [26]	validation_0-rmse:0.394002	validation_1-rmse:0.483723
# [27]	validation_0-rmse:0.392294	validation_1-rmse:0.482961
# [28]	validation_0-rmse:0.388213	validation_1-rmse:0.48381
# [29]	validation_0-rmse:0.387105	validation_1-rmse:0.483348
# [30]	validation_0-rmse:0.386205	validation_1-rmse:0.483016
# [31]	validation_0-rmse:0.385416	validation_1-rmse:0.482772
# [32]	validation_0-rmse:0.384818	validation_1-rmse:0.482615
# [33]	validation_0-rmse:0.381875	validation_1-rmse:0.485048
# [34]	validation_0-rmse:0.381488	validation_1-rmse:0.485011
# [35]	validation_0-rmse:0.381158	validation_1-rmse:0.485032
# [36]	validation_0-rmse:0.379864	validation_1-rmse:0.48588
# [37]	validation_0-rmse:0.378813	validation_1-rmse:0.486737
# [38]	validation_0-rmse:0.378646	validation_1-rmse:0.486834
# [39]	validation_0-rmse:0.378492	validation_1-rmse:0.486955
# [40]	validation_0-rmse:0.376594	validation_1-rmse:0.488961
# [41]	validation_0-rmse:0.376408	validation_1-rmse:0.489301
# [42]	validation_0-rmse:0.374841	validation_1-rmse:0.491793
# Stopping. Best iteration:
# [32]	validation_0-rmse:0.384818	validation_1-rmse:0.482615
#
# [0]	validation_0-rmse:1.2713	validation_1-rmse:1.27229
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 10 rounds.
# [1]	validation_0-rmse:1.15657	validation_1-rmse:1.16118
# [2]	validation_0-rmse:1.05532	validation_1-rmse:1.06333
# [3]	validation_0-rmse:0.970117	validation_1-rmse:0.978906
# [4]	validation_0-rmse:0.889093	validation_1-rmse:0.902629
# [5]	validation_0-rmse:0.81821	validation_1-rmse:0.836744
# [6]	validation_0-rmse:0.759621	validation_1-rmse:0.780018
# [7]	validation_0-rmse:0.707308	validation_1-rmse:0.729417
# [8]	validation_0-rmse:0.657692	validation_1-rmse:0.686465
# [9]	validation_0-rmse:0.618945	validation_1-rmse:0.650528
# [10]	validation_0-rmse:0.58478	validation_1-rmse:0.619505
# [11]	validation_0-rmse:0.555548	validation_1-rmse:0.593215
# [12]	validation_0-rmse:0.526563	validation_1-rmse:0.571272
# [13]	validation_0-rmse:0.508494	validation_1-rmse:0.555787
# [14]	validation_0-rmse:0.490263	validation_1-rmse:0.54053
# [15]	validation_0-rmse:0.470775	validation_1-rmse:0.527974
# [16]	validation_0-rmse:0.45751	validation_1-rmse:0.517053
# [17]	validation_0-rmse:0.443348	validation_1-rmse:0.509079
# [18]	validation_0-rmse:0.435689	validation_1-rmse:0.503313
# [19]	validation_0-rmse:0.428047	validation_1-rmse:0.497615
# [20]	validation_0-rmse:0.421544	validation_1-rmse:0.492762
# [21]	validation_0-rmse:0.416252	validation_1-rmse:0.489003
# [22]	validation_0-rmse:0.41182	validation_1-rmse:0.485909
# [23]	validation_0-rmse:0.408109	validation_1-rmse:0.483409
# [24]	validation_0-rmse:0.405052	validation_1-rmse:0.481293
# [25]	validation_0-rmse:0.400435	validation_1-rmse:0.480389
# [26]	validation_0-rmse:0.398508	validation_1-rmse:0.479239
# [27]	validation_0-rmse:0.396807	validation_1-rmse:0.478314
# [28]	validation_0-rmse:0.393019	validation_1-rmse:0.478447
# [29]	validation_0-rmse:0.391885	validation_1-rmse:0.477868
# [30]	validation_0-rmse:0.390964	validation_1-rmse:0.477431
# [31]	validation_0-rmse:0.390163	validation_1-rmse:0.477102
# [32]	validation_0-rmse:0.389549	validation_1-rmse:0.476866
# [33]	validation_0-rmse:0.386718	validation_1-rmse:0.478618
# [34]	validation_0-rmse:0.386324	validation_1-rmse:0.478529
# [35]	validation_0-rmse:0.385983	validation_1-rmse:0.478486
# [36]	validation_0-rmse:0.384638	validation_1-rmse:0.479228
# [37]	validation_0-rmse:0.383541	validation_1-rmse:0.479997
# [38]	validation_0-rmse:0.383369	validation_1-rmse:0.480034
# [39]	validation_0-rmse:0.383208	validation_1-rmse:0.480101
# [40]	validation_0-rmse:0.381645	validation_1-rmse:0.481196
# [41]	validation_0-rmse:0.381456	validation_1-rmse:0.481359
# [42]	validation_0-rmse:0.380001	validation_1-rmse:0.482799
# Stopping. Best iteration:
# [32]	validation_0-rmse:0.389549	validation_1-rmse:0.476866
#
# [0]	validation_0-rmse:1.27062	validation_1-rmse:1.27061
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 10 rounds.
# [1]	validation_0-rmse:1.15522	validation_1-rmse:1.1583
# [2]	validation_0-rmse:1.0534	validation_1-rmse:1.06025
# [3]	validation_0-rmse:0.967763	validation_1-rmse:0.975789
# [4]	validation_0-rmse:0.886074	validation_1-rmse:0.899275
# [5]	validation_0-rmse:0.814686	validation_1-rmse:0.833603
# [6]	validation_0-rmse:0.755804	validation_1-rmse:0.777154
# [7]	validation_0-rmse:0.703277	validation_1-rmse:0.726847
# [8]	validation_0-rmse:0.6531	validation_1-rmse:0.684543
# [9]	validation_0-rmse:0.614017	validation_1-rmse:0.649014
# [10]	validation_0-rmse:0.579615	validation_1-rmse:0.618332
# [11]	validation_0-rmse:0.550175	validation_1-rmse:0.592501
# [12]	validation_0-rmse:0.520727	validation_1-rmse:0.571954
# [13]	validation_0-rmse:0.502177	validation_1-rmse:0.556698
# [14]	validation_0-rmse:0.483679	validation_1-rmse:0.541916
# [15]	validation_0-rmse:0.463744	validation_1-rmse:0.531601
# [16]	validation_0-rmse:0.450429	validation_1-rmse:0.521219
# [17]	validation_0-rmse:0.435971	validation_1-rmse:0.515219
# [18]	validation_0-rmse:0.428166	validation_1-rmse:0.5099
# [19]	validation_0-rmse:0.420433	validation_1-rmse:0.504579
# [20]	validation_0-rmse:0.413894	validation_1-rmse:0.500223
# [21]	validation_0-rmse:0.408487	validation_1-rmse:0.496803
# [22]	validation_0-rmse:0.404078	validation_1-rmse:0.494105
# [23]	validation_0-rmse:0.400358	validation_1-rmse:0.491972
# [24]	validation_0-rmse:0.397292	validation_1-rmse:0.490219
# [25]	validation_0-rmse:0.392671	validation_1-rmse:0.489758
# [26]	validation_0-rmse:0.390734	validation_1-rmse:0.488791
# [27]	validation_0-rmse:0.389022	validation_1-rmse:0.488181
# [28]	validation_0-rmse:0.384739	validation_1-rmse:0.489799
# [29]	validation_0-rmse:0.383643	validation_1-rmse:0.489428
# [30]	validation_0-rmse:0.382752	validation_1-rmse:0.489176
# [31]	validation_0-rmse:0.381954	validation_1-rmse:0.488998
# [32]	validation_0-rmse:0.381365	validation_1-rmse:0.488905
# [33]	validation_0-rmse:0.378203	validation_1-rmse:0.492336
# [34]	validation_0-rmse:0.377821	validation_1-rmse:0.492336
# [35]	validation_0-rmse:0.377499	validation_1-rmse:0.492411
# [36]	validation_0-rmse:0.376244	validation_1-rmse:0.493338
# [37]	validation_0-rmse:0.375225	validation_1-rmse:0.494258
# Stopping. Best iteration:
# [27]	validation_0-rmse:0.389022	validation_1-rmse:0.488181
#
# Parameters are finished for max_depth. Best Iteration is 32
# Minimum Rmse : 0.476866, optimum parameter is 6 between [12, 8, 6, 14]
# [0]	validation_0-rmse:1.2799	validation_1-rmse:1.27688
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 10 rounds.
# [1]	validation_0-rmse:1.1642	validation_1-rmse:1.16442
# [2]	validation_0-rmse:1.06138	validation_1-rmse:1.0632
# [3]	validation_0-rmse:0.97707	validation_1-rmse:0.979168
# [4]	validation_0-rmse:0.901379	validation_1-rmse:0.904476
# [5]	validation_0-rmse:0.836059	validation_1-rmse:0.841276
# [6]	validation_0-rmse:0.771195	validation_1-rmse:0.780335
# [7]	validation_0-rmse:0.720476	validation_1-rmse:0.730883
# [8]	validation_0-rmse:0.676082	validation_1-rmse:0.688481
# [9]	validation_0-rmse:0.637344	validation_1-rmse:0.651294
# [10]	validation_0-rmse:0.60394	validation_1-rmse:0.619204
# [11]	validation_0-rmse:0.569089	validation_1-rmse:0.590988
# [12]	validation_0-rmse:0.544995	validation_1-rmse:0.569201
# [13]	validation_0-rmse:0.525099	validation_1-rmse:0.551029
# [14]	validation_0-rmse:0.508222	validation_1-rmse:0.536136
# [15]	validation_0-rmse:0.487495	validation_1-rmse:0.52221
# [16]	validation_0-rmse:0.475025	validation_1-rmse:0.51132
# [17]	validation_0-rmse:0.464658	validation_1-rmse:0.502393
# [18]	validation_0-rmse:0.456082	validation_1-rmse:0.495253
# [19]	validation_0-rmse:0.449645	validation_1-rmse:0.490095
# [20]	validation_0-rmse:0.439348	validation_1-rmse:0.484649
# [21]	validation_0-rmse:0.434585	validation_1-rmse:0.481141
# [22]	validation_0-rmse:0.430909	validation_1-rmse:0.478415
# [23]	validation_0-rmse:0.427592	validation_1-rmse:0.476098
# [24]	validation_0-rmse:0.424876	validation_1-rmse:0.474264
# [25]	validation_0-rmse:0.419397	validation_1-rmse:0.472617
# [26]	validation_0-rmse:0.417413	validation_1-rmse:0.471261
# [27]	validation_0-rmse:0.415812	validation_1-rmse:0.470356
# [28]	validation_0-rmse:0.410498	validation_1-rmse:0.470271
# [29]	validation_0-rmse:0.407344	validation_1-rmse:0.470116
# [30]	validation_0-rmse:0.406472	validation_1-rmse:0.469859
# [31]	validation_0-rmse:0.405866	validation_1-rmse:0.469693
# [32]	validation_0-rmse:0.405257	validation_1-rmse:0.469604
# [33]	validation_0-rmse:0.404577	validation_1-rmse:0.469382
# [34]	validation_0-rmse:0.404253	validation_1-rmse:0.469282
# [35]	validation_0-rmse:0.400767	validation_1-rmse:0.470131
# [36]	validation_0-rmse:0.399095	validation_1-rmse:0.470743
# [37]	validation_0-rmse:0.398896	validation_1-rmse:0.470791
# [38]	validation_0-rmse:0.398634	validation_1-rmse:0.470919
# [39]	validation_0-rmse:0.398325	validation_1-rmse:0.470842
# [40]	validation_0-rmse:0.395752	validation_1-rmse:0.471772
# [41]	validation_0-rmse:0.395472	validation_1-rmse:0.471715
# [42]	validation_0-rmse:0.395329	validation_1-rmse:0.471934
# [43]	validation_0-rmse:0.393208	validation_1-rmse:0.473045
# [44]	validation_0-rmse:0.393134	validation_1-rmse:0.473076
# Stopping. Best iteration:
# [34]	validation_0-rmse:0.404253	validation_1-rmse:0.469282
#
# [0]	validation_0-rmse:1.27993	validation_1-rmse:1.2769
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 10 rounds.
# [1]	validation_0-rmse:1.1642	validation_1-rmse:1.16435
# [2]	validation_0-rmse:1.06137	validation_1-rmse:1.06314
# [3]	validation_0-rmse:0.977057	validation_1-rmse:0.979091
# [4]	validation_0-rmse:0.901342	validation_1-rmse:0.9044
# [5]	validation_0-rmse:0.836014	validation_1-rmse:0.841205
# [6]	validation_0-rmse:0.771154	validation_1-rmse:0.780294
# [7]	validation_0-rmse:0.720456	validation_1-rmse:0.730851
# [8]	validation_0-rmse:0.676058	validation_1-rmse:0.68846
# [9]	validation_0-rmse:0.637315	validation_1-rmse:0.651282
# [10]	validation_0-rmse:0.603923	validation_1-rmse:0.619301
# [11]	validation_0-rmse:0.569059	validation_1-rmse:0.5911
# [12]	validation_0-rmse:0.544976	validation_1-rmse:0.569296
# [13]	validation_0-rmse:0.52508	validation_1-rmse:0.551134
# [14]	validation_0-rmse:0.508201	validation_1-rmse:0.536242
# [15]	validation_0-rmse:0.487454	validation_1-rmse:0.522329
# [16]	validation_0-rmse:0.474985	validation_1-rmse:0.511458
# [17]	validation_0-rmse:0.464628	validation_1-rmse:0.502519
# [18]	validation_0-rmse:0.45605	validation_1-rmse:0.495393
# [19]	validation_0-rmse:0.449616	validation_1-rmse:0.490245
# [20]	validation_0-rmse:0.439308	validation_1-rmse:0.484804
# [21]	validation_0-rmse:0.434544	validation_1-rmse:0.481306
# [22]	validation_0-rmse:0.430867	validation_1-rmse:0.478584
# [23]	validation_0-rmse:0.427548	validation_1-rmse:0.476274
# [24]	validation_0-rmse:0.424838	validation_1-rmse:0.474418
# [25]	validation_0-rmse:0.419346	validation_1-rmse:0.472785
# [26]	validation_0-rmse:0.417338	validation_1-rmse:0.471409
# [27]	validation_0-rmse:0.415735	validation_1-rmse:0.470506
# [28]	validation_0-rmse:0.410419	validation_1-rmse:0.470426
# [29]	validation_0-rmse:0.407266	validation_1-rmse:0.470289
# [30]	validation_0-rmse:0.406401	validation_1-rmse:0.470044
# [31]	validation_0-rmse:0.405778	validation_1-rmse:0.469846
# [32]	validation_0-rmse:0.405168	validation_1-rmse:0.46976
# [33]	validation_0-rmse:0.40449	validation_1-rmse:0.469542
# [34]	validation_0-rmse:0.404171	validation_1-rmse:0.469445
# [35]	validation_0-rmse:0.400654	validation_1-rmse:0.470322
# [36]	validation_0-rmse:0.398985	validation_1-rmse:0.470944
# [37]	validation_0-rmse:0.398789	validation_1-rmse:0.470993
# [38]	validation_0-rmse:0.398524	validation_1-rmse:0.471126
# [39]	validation_0-rmse:0.398211	validation_1-rmse:0.47105
# [40]	validation_0-rmse:0.395629	validation_1-rmse:0.471996
# [41]	validation_0-rmse:0.395349	validation_1-rmse:0.471941
# [42]	validation_0-rmse:0.395207	validation_1-rmse:0.472126
# [43]	validation_0-rmse:0.393086	validation_1-rmse:0.473257
# [44]	validation_0-rmse:0.393012	validation_1-rmse:0.473291
# Stopping. Best iteration:
# [34]	validation_0-rmse:0.404171	validation_1-rmse:0.469445
#
# [0]	validation_0-rmse:1.27991	validation_1-rmse:1.27688
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 10 rounds.
# [1]	validation_0-rmse:1.16418	validation_1-rmse:1.1643
# [2]	validation_0-rmse:1.06134	validation_1-rmse:1.06307
# [3]	validation_0-rmse:0.977021	validation_1-rmse:0.979017
# [4]	validation_0-rmse:0.901331	validation_1-rmse:0.904335
# [5]	validation_0-rmse:0.836013	validation_1-rmse:0.841158
# [6]	validation_0-rmse:0.77115	validation_1-rmse:0.780243
# [7]	validation_0-rmse:0.720433	validation_1-rmse:0.730807
# [8]	validation_0-rmse:0.676024	validation_1-rmse:0.688413
# [9]	validation_0-rmse:0.637293	validation_1-rmse:0.651255
# [10]	validation_0-rmse:0.60386	validation_1-rmse:0.619102
# [11]	validation_0-rmse:0.568991	validation_1-rmse:0.590895
# [12]	validation_0-rmse:0.544914	validation_1-rmse:0.569132
# [13]	validation_0-rmse:0.52503	validation_1-rmse:0.550984
# [14]	validation_0-rmse:0.508147	validation_1-rmse:0.536095
# [15]	validation_0-rmse:0.487375	validation_1-rmse:0.522171
# [16]	validation_0-rmse:0.474904	validation_1-rmse:0.511302
# [17]	validation_0-rmse:0.464546	validation_1-rmse:0.502387
# [18]	validation_0-rmse:0.455974	validation_1-rmse:0.495268
# [19]	validation_0-rmse:0.449544	validation_1-rmse:0.490128
# [20]	validation_0-rmse:0.439248	validation_1-rmse:0.484712
# [21]	validation_0-rmse:0.434479	validation_1-rmse:0.481216
# [22]	validation_0-rmse:0.430808	validation_1-rmse:0.478501
# [23]	validation_0-rmse:0.427492	validation_1-rmse:0.476192
# [24]	validation_0-rmse:0.42479	validation_1-rmse:0.474357
# [25]	validation_0-rmse:0.419304	validation_1-rmse:0.472721
# [26]	validation_0-rmse:0.417317	validation_1-rmse:0.471386
# [27]	validation_0-rmse:0.415718	validation_1-rmse:0.470479
# [28]	validation_0-rmse:0.410395	validation_1-rmse:0.470388
# [29]	validation_0-rmse:0.407238	validation_1-rmse:0.470239
# [30]	validation_0-rmse:0.406371	validation_1-rmse:0.469989
# [31]	validation_0-rmse:0.405747	validation_1-rmse:0.469799
# [32]	validation_0-rmse:0.40514	validation_1-rmse:0.469718
# [33]	validation_0-rmse:0.404462	validation_1-rmse:0.469505
# [34]	validation_0-rmse:0.404139	validation_1-rmse:0.46941
# [35]	validation_0-rmse:0.400625	validation_1-rmse:0.470284
# [36]	validation_0-rmse:0.398954	validation_1-rmse:0.470905
# [37]	validation_0-rmse:0.398755	validation_1-rmse:0.470957
# [38]	validation_0-rmse:0.398491	validation_1-rmse:0.471096
# [39]	validation_0-rmse:0.398185	validation_1-rmse:0.471002
# [40]	validation_0-rmse:0.395604	validation_1-rmse:0.471945
# [41]	validation_0-rmse:0.395327	validation_1-rmse:0.471889
# [42]	validation_0-rmse:0.395177	validation_1-rmse:0.472102
# [43]	validation_0-rmse:0.392922	validation_1-rmse:0.473354
# [44]	validation_0-rmse:0.392845	validation_1-rmse:0.473388
# Stopping. Best iteration:
# [34]	validation_0-rmse:0.404139	validation_1-rmse:0.46941
#
# Parameters are finished for subsample. Best Iteration is 34
# Minimum Rmse : 0.469282, optimum parameter is 0.9 between [0.9, 0.8, 0.6]
# [0]	validation_0-rmse:1.2799	validation_1-rmse:1.27688
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 10 rounds.
# [1]	validation_0-rmse:1.1642	validation_1-rmse:1.16442
# [2]	validation_0-rmse:1.06138	validation_1-rmse:1.0632
# [3]	validation_0-rmse:0.97707	validation_1-rmse:0.979168
# [4]	validation_0-rmse:0.901379	validation_1-rmse:0.904476
# [5]	validation_0-rmse:0.836059	validation_1-rmse:0.841276
# [6]	validation_0-rmse:0.771195	validation_1-rmse:0.780335
# [7]	validation_0-rmse:0.720476	validation_1-rmse:0.730883
# [8]	validation_0-rmse:0.676082	validation_1-rmse:0.688481
# [9]	validation_0-rmse:0.637344	validation_1-rmse:0.651294
# [10]	validation_0-rmse:0.60394	validation_1-rmse:0.619204
# [11]	validation_0-rmse:0.569089	validation_1-rmse:0.590988
# [12]	validation_0-rmse:0.544995	validation_1-rmse:0.569201
# [13]	validation_0-rmse:0.525099	validation_1-rmse:0.551029
# [14]	validation_0-rmse:0.508222	validation_1-rmse:0.536136
# [15]	validation_0-rmse:0.487495	validation_1-rmse:0.52221
# [16]	validation_0-rmse:0.475025	validation_1-rmse:0.51132
# [17]	validation_0-rmse:0.464658	validation_1-rmse:0.502393
# [18]	validation_0-rmse:0.456082	validation_1-rmse:0.495253
# [19]	validation_0-rmse:0.449644	validation_1-rmse:0.490095
# [20]	validation_0-rmse:0.439348	validation_1-rmse:0.484649
# [21]	validation_0-rmse:0.434585	validation_1-rmse:0.481141
# [22]	validation_0-rmse:0.430908	validation_1-rmse:0.478415
# [23]	validation_0-rmse:0.427592	validation_1-rmse:0.476098
# [24]	validation_0-rmse:0.424876	validation_1-rmse:0.474264
# [25]	validation_0-rmse:0.419396	validation_1-rmse:0.472618
# [26]	validation_0-rmse:0.417413	validation_1-rmse:0.471261
# [27]	validation_0-rmse:0.415812	validation_1-rmse:0.470356
# [28]	validation_0-rmse:0.410497	validation_1-rmse:0.470271
# [29]	validation_0-rmse:0.407344	validation_1-rmse:0.470116
# [30]	validation_0-rmse:0.406471	validation_1-rmse:0.46986
# [31]	validation_0-rmse:0.405865	validation_1-rmse:0.469693
# [32]	validation_0-rmse:0.405257	validation_1-rmse:0.469604
# [33]	validation_0-rmse:0.404577	validation_1-rmse:0.469382
# [34]	validation_0-rmse:0.404252	validation_1-rmse:0.469282
# [35]	validation_0-rmse:0.400767	validation_1-rmse:0.470131
# [36]	validation_0-rmse:0.399094	validation_1-rmse:0.470743
# [37]	validation_0-rmse:0.398896	validation_1-rmse:0.470791
# [38]	validation_0-rmse:0.398634	validation_1-rmse:0.470919
# [39]	validation_0-rmse:0.398324	validation_1-rmse:0.470842
# [40]	validation_0-rmse:0.395752	validation_1-rmse:0.471772
# [41]	validation_0-rmse:0.395472	validation_1-rmse:0.471715
# [42]	validation_0-rmse:0.395329	validation_1-rmse:0.471934
# [43]	validation_0-rmse:0.393208	validation_1-rmse:0.473045
# [44]	validation_0-rmse:0.393133	validation_1-rmse:0.473076
# Stopping. Best iteration:
# [34]	validation_0-rmse:0.404252	validation_1-rmse:0.469282
#
# [0]	validation_0-rmse:1.2799	validation_1-rmse:1.27688
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 10 rounds.
# [1]	validation_0-rmse:1.1642	validation_1-rmse:1.16442
# [2]	validation_0-rmse:1.06138	validation_1-rmse:1.0632
# [3]	validation_0-rmse:0.97707	validation_1-rmse:0.979168
# [4]	validation_0-rmse:0.901379	validation_1-rmse:0.904476
# [5]	validation_0-rmse:0.836059	validation_1-rmse:0.841276
# [6]	validation_0-rmse:0.771195	validation_1-rmse:0.780335
# [7]	validation_0-rmse:0.720476	validation_1-rmse:0.730883
# [8]	validation_0-rmse:0.676082	validation_1-rmse:0.688481
# [9]	validation_0-rmse:0.637344	validation_1-rmse:0.651294
# [10]	validation_0-rmse:0.60394	validation_1-rmse:0.619204
# [11]	validation_0-rmse:0.569089	validation_1-rmse:0.590988
# [12]	validation_0-rmse:0.544995	validation_1-rmse:0.569201
# [13]	validation_0-rmse:0.525099	validation_1-rmse:0.551029
# [14]	validation_0-rmse:0.508222	validation_1-rmse:0.536136
# [15]	validation_0-rmse:0.487495	validation_1-rmse:0.52221
# [16]	validation_0-rmse:0.475025	validation_1-rmse:0.51132
# [17]	validation_0-rmse:0.464658	validation_1-rmse:0.502393
# [18]	validation_0-rmse:0.456082	validation_1-rmse:0.495253
# [19]	validation_0-rmse:0.449645	validation_1-rmse:0.490095
# [20]	validation_0-rmse:0.439348	validation_1-rmse:0.484649
# [21]	validation_0-rmse:0.434585	validation_1-rmse:0.481141
# [22]	validation_0-rmse:0.430909	validation_1-rmse:0.478415
# [23]	validation_0-rmse:0.427592	validation_1-rmse:0.476098
# [24]	validation_0-rmse:0.424876	validation_1-rmse:0.474264
# [25]	validation_0-rmse:0.419397	validation_1-rmse:0.472617
# [26]	validation_0-rmse:0.417413	validation_1-rmse:0.471261
# [27]	validation_0-rmse:0.415812	validation_1-rmse:0.470356
# [28]	validation_0-rmse:0.410498	validation_1-rmse:0.470271
# [29]	validation_0-rmse:0.407344	validation_1-rmse:0.470116
# [30]	validation_0-rmse:0.406472	validation_1-rmse:0.46986
# [31]	validation_0-rmse:0.405866	validation_1-rmse:0.469693
# [32]	validation_0-rmse:0.405257	validation_1-rmse:0.469604
# [33]	validation_0-rmse:0.404577	validation_1-rmse:0.469382
# [34]	validation_0-rmse:0.404253	validation_1-rmse:0.469282
# [35]	validation_0-rmse:0.400767	validation_1-rmse:0.470131
# [36]	validation_0-rmse:0.399095	validation_1-rmse:0.470743
# [37]	validation_0-rmse:0.398896	validation_1-rmse:0.470791
# [38]	validation_0-rmse:0.398634	validation_1-rmse:0.470919
# [39]	validation_0-rmse:0.398325	validation_1-rmse:0.470842
# [40]	validation_0-rmse:0.395752	validation_1-rmse:0.471773
# [41]	validation_0-rmse:0.395472	validation_1-rmse:0.471715
# [42]	validation_0-rmse:0.395329	validation_1-rmse:0.471934
# [43]	validation_0-rmse:0.393208	validation_1-rmse:0.473045
# [44]	validation_0-rmse:0.393134	validation_1-rmse:0.473076
# Stopping. Best iteration:
# [34]	validation_0-rmse:0.404253	validation_1-rmse:0.469282
#
# [0]	validation_0-rmse:1.2799	validation_1-rmse:1.27688
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 10 rounds.
# [1]	validation_0-rmse:1.1642	validation_1-rmse:1.16442
# [2]	validation_0-rmse:1.06138	validation_1-rmse:1.0632
# [3]	validation_0-rmse:0.97707	validation_1-rmse:0.979168
# [4]	validation_0-rmse:0.901379	validation_1-rmse:0.904476
# [5]	validation_0-rmse:0.836059	validation_1-rmse:0.841276
# [6]	validation_0-rmse:0.771195	validation_1-rmse:0.780335
# [7]	validation_0-rmse:0.720476	validation_1-rmse:0.730883
# [8]	validation_0-rmse:0.676082	validation_1-rmse:0.688481
# [9]	validation_0-rmse:0.637344	validation_1-rmse:0.651294
# [10]	validation_0-rmse:0.60394	validation_1-rmse:0.619204
# [11]	validation_0-rmse:0.569089	validation_1-rmse:0.590988
# [12]	validation_0-rmse:0.544995	validation_1-rmse:0.569201
# [13]	validation_0-rmse:0.525099	validation_1-rmse:0.551029
# [14]	validation_0-rmse:0.508222	validation_1-rmse:0.536136
# [15]	validation_0-rmse:0.487495	validation_1-rmse:0.52221
# [16]	validation_0-rmse:0.475025	validation_1-rmse:0.51132
# [17]	validation_0-rmse:0.464658	validation_1-rmse:0.502393
# [18]	validation_0-rmse:0.456082	validation_1-rmse:0.495253
# [19]	validation_0-rmse:0.449645	validation_1-rmse:0.490095
# [20]	validation_0-rmse:0.439348	validation_1-rmse:0.484649
# [21]	validation_0-rmse:0.434585	validation_1-rmse:0.481141
# [22]	validation_0-rmse:0.430909	validation_1-rmse:0.478415
# [23]	validation_0-rmse:0.427592	validation_1-rmse:0.476098
# [24]	validation_0-rmse:0.424876	validation_1-rmse:0.474264
# [25]	validation_0-rmse:0.419397	validation_1-rmse:0.472617
# [26]	validation_0-rmse:0.417413	validation_1-rmse:0.471261
# [27]	validation_0-rmse:0.415812	validation_1-rmse:0.470356
# [28]	validation_0-rmse:0.410498	validation_1-rmse:0.470271
# [29]	validation_0-rmse:0.407344	validation_1-rmse:0.470116
# [30]	validation_0-rmse:0.406472	validation_1-rmse:0.469859
# [31]	validation_0-rmse:0.405866	validation_1-rmse:0.469693
# [32]	validation_0-rmse:0.405257	validation_1-rmse:0.469604
# [33]	validation_0-rmse:0.404577	validation_1-rmse:0.469382
# [34]	validation_0-rmse:0.404253	validation_1-rmse:0.469282
# [35]	validation_0-rmse:0.400767	validation_1-rmse:0.470131
# [36]	validation_0-rmse:0.399095	validation_1-rmse:0.470743
# [37]	validation_0-rmse:0.398896	validation_1-rmse:0.470791
# [38]	validation_0-rmse:0.398634	validation_1-rmse:0.470919
# [39]	validation_0-rmse:0.398325	validation_1-rmse:0.470842
# [40]	validation_0-rmse:0.395752	validation_1-rmse:0.471772
# [41]	validation_0-rmse:0.395472	validation_1-rmse:0.471715
# [42]	validation_0-rmse:0.395329	validation_1-rmse:0.471934
# [43]	validation_0-rmse:0.393208	validation_1-rmse:0.473045
# [44]	validation_0-rmse:0.393134	validation_1-rmse:0.473076
# Stopping. Best iteration:
# [34]	validation_0-rmse:0.404253	validation_1-rmse:0.469282
#
# Parameters are finished for min_child_weight. Best Iteration is 34
# Minimum Rmse : 0.469282, optimum parameter is 5 between [1, 3, 7]
# [0]	validation_0-rmse:1.28	validation_1-rmse:1.27693
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 10 rounds.
# [1]	validation_0-rmse:1.17366	validation_1-rmse:1.17222
# [2]	validation_0-rmse:1.07184	validation_1-rmse:1.07378
# [3]	validation_0-rmse:1.00248	validation_1-rmse:1.00538
# [4]	validation_0-rmse:0.926778	validation_1-rmse:0.92948
# [5]	validation_0-rmse:0.876199	validation_1-rmse:0.879381
# [6]	validation_0-rmse:0.816455	validation_1-rmse:0.819712
# [7]	validation_0-rmse:0.778927	validation_1-rmse:0.782744
# [8]	validation_0-rmse:0.732248	validation_1-rmse:0.736313
# [9]	validation_0-rmse:0.69076	validation_1-rmse:0.696609
# [10]	validation_0-rmse:0.655996	validation_1-rmse:0.662316
# [11]	validation_0-rmse:0.625274	validation_1-rmse:0.63321
# [12]	validation_0-rmse:0.59993	validation_1-rmse:0.608426
# [13]	validation_0-rmse:0.585743	validation_1-rmse:0.594841
# [14]	validation_0-rmse:0.573992	validation_1-rmse:0.583648
# [15]	validation_0-rmse:0.546622	validation_1-rmse:0.562277
# [16]	validation_0-rmse:0.5296	validation_1-rmse:0.545904
# [17]	validation_0-rmse:0.517592	validation_1-rmse:0.534456
# [18]	validation_0-rmse:0.506666	validation_1-rmse:0.524707
# [19]	validation_0-rmse:0.50078	validation_1-rmse:0.519482
# [20]	validation_0-rmse:0.495995	validation_1-rmse:0.515256
# [21]	validation_0-rmse:0.489421	validation_1-rmse:0.50915
# [22]	validation_0-rmse:0.48689	validation_1-rmse:0.506969
# [23]	validation_0-rmse:0.481964	validation_1-rmse:0.502455
# [24]	validation_0-rmse:0.477119	validation_1-rmse:0.498358
# [25]	validation_0-rmse:0.466185	validation_1-rmse:0.492451
# [26]	validation_0-rmse:0.463619	validation_1-rmse:0.49019
# [27]	validation_0-rmse:0.459775	validation_1-rmse:0.48676
# [28]	validation_0-rmse:0.456652	validation_1-rmse:0.483995
# [29]	validation_0-rmse:0.449616	validation_1-rmse:0.4812
# [30]	validation_0-rmse:0.447594	validation_1-rmse:0.479532
# [31]	validation_0-rmse:0.446482	validation_1-rmse:0.478802
# [32]	validation_0-rmse:0.446088	validation_1-rmse:0.47853
# [33]	validation_0-rmse:0.44468	validation_1-rmse:0.477406
# [34]	validation_0-rmse:0.444396	validation_1-rmse:0.477214
# [35]	validation_0-rmse:0.443724	validation_1-rmse:0.476822
# [36]	validation_0-rmse:0.439181	validation_1-rmse:0.475832
# [37]	validation_0-rmse:0.438976	validation_1-rmse:0.475689
# [38]	validation_0-rmse:0.438758	validation_1-rmse:0.475527
# [39]	validation_0-rmse:0.438388	validation_1-rmse:0.475378
# [40]	validation_0-rmse:0.438227	validation_1-rmse:0.475265
# [41]	validation_0-rmse:0.438102	validation_1-rmse:0.475171
# [42]	validation_0-rmse:0.437453	validation_1-rmse:0.47475
# [43]	validation_0-rmse:0.433998	validation_1-rmse:0.474423
# [44]	validation_0-rmse:0.433821	validation_1-rmse:0.474411
# [45]	validation_0-rmse:0.433445	validation_1-rmse:0.474257
# [46]	validation_0-rmse:0.433215	validation_1-rmse:0.474175
# [47]	validation_0-rmse:0.433166	validation_1-rmse:0.474143
# [48]	validation_0-rmse:0.433061	validation_1-rmse:0.47416
# [49]	validation_0-rmse:0.433026	validation_1-rmse:0.474144
# [50]	validation_0-rmse:0.432946	validation_1-rmse:0.474171
# [51]	validation_0-rmse:0.432687	validation_1-rmse:0.474091
# [52]	validation_0-rmse:0.432564	validation_1-rmse:0.473958
# [53]	validation_0-rmse:0.432508	validation_1-rmse:0.473986
# [54]	validation_0-rmse:0.432484	validation_1-rmse:0.473974
# [55]	validation_0-rmse:0.432441	validation_1-rmse:0.474006
# [56]	validation_0-rmse:0.432339	validation_1-rmse:0.47389
# [57]	validation_0-rmse:0.432323	validation_1-rmse:0.473884
# [58]	validation_0-rmse:0.432186	validation_1-rmse:0.473867
# [59]	validation_0-rmse:0.432075	validation_1-rmse:0.473863
# [60]	validation_0-rmse:0.43199	validation_1-rmse:0.473758
# [61]	validation_0-rmse:0.431776	validation_1-rmse:0.473682
# [62]	validation_0-rmse:0.431742	validation_1-rmse:0.473713
# [63]	validation_0-rmse:0.429067	validation_1-rmse:0.473856
# [64]	validation_0-rmse:0.428944	validation_1-rmse:0.473888
# [65]	validation_0-rmse:0.428889	validation_1-rmse:0.473845
# [66]	validation_0-rmse:0.42874	validation_1-rmse:0.473769
# [67]	validation_0-rmse:0.428661	validation_1-rmse:0.473659
# [68]	validation_0-rmse:0.428597	validation_1-rmse:0.473567
# [69]	validation_0-rmse:0.428544	validation_1-rmse:0.473488
# [70]	validation_0-rmse:0.428522	validation_1-rmse:0.473518
# [71]	validation_0-rmse:0.426246	validation_1-rmse:0.473835
# [72]	validation_0-rmse:0.426188	validation_1-rmse:0.473749
# [73]	validation_0-rmse:0.426111	validation_1-rmse:0.473699
# [74]	validation_0-rmse:0.426014	validation_1-rmse:0.473736
# [75]	validation_0-rmse:0.425946	validation_1-rmse:0.473688
# [76]	validation_0-rmse:0.425839	validation_1-rmse:0.473618
# [77]	validation_0-rmse:0.425758	validation_1-rmse:0.473658
# [78]	validation_0-rmse:0.425712	validation_1-rmse:0.473592
# [79]	validation_0-rmse:0.425656	validation_1-rmse:0.473554
# Stopping. Best iteration:
# [69]	validation_0-rmse:0.428544	validation_1-rmse:0.473488
#
# [0]	validation_0-rmse:1.27779	validation_1-rmse:1.2755
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 10 rounds.
# [1]	validation_0-rmse:1.16209	validation_1-rmse:1.16321
# [2]	validation_0-rmse:1.05922	validation_1-rmse:1.0624
# [3]	validation_0-rmse:0.967875	validation_1-rmse:0.97397
# [4]	validation_0-rmse:0.886725	validation_1-rmse:0.897603
# [5]	validation_0-rmse:0.819808	validation_1-rmse:0.832561
# [6]	validation_0-rmse:0.75646	validation_1-rmse:0.773542
# [7]	validation_0-rmse:0.700666	validation_1-rmse:0.723401
# [8]	validation_0-rmse:0.655633	validation_1-rmse:0.681493
# [9]	validation_0-rmse:0.616377	validation_1-rmse:0.644669
# [10]	validation_0-rmse:0.57858	validation_1-rmse:0.612906
# [11]	validation_0-rmse:0.545906	validation_1-rmse:0.587249
# [12]	validation_0-rmse:0.521038	validation_1-rmse:0.565565
# [13]	validation_0-rmse:0.497086	validation_1-rmse:0.547546
# [14]	validation_0-rmse:0.479397	validation_1-rmse:0.532999
# [15]	validation_0-rmse:0.461378	validation_1-rmse:0.521771
# [16]	validation_0-rmse:0.448732	validation_1-rmse:0.511993
# [17]	validation_0-rmse:0.437976	validation_1-rmse:0.503801
# [18]	validation_0-rmse:0.426341	validation_1-rmse:0.498376
# [19]	validation_0-rmse:0.418964	validation_1-rmse:0.49313
# [20]	validation_0-rmse:0.410661	validation_1-rmse:0.490182
# [21]	validation_0-rmse:0.40367	validation_1-rmse:0.488524
# [22]	validation_0-rmse:0.3994	validation_1-rmse:0.485875
# [23]	validation_0-rmse:0.395914	validation_1-rmse:0.483844
# [24]	validation_0-rmse:0.393178	validation_1-rmse:0.482407
# [25]	validation_0-rmse:0.389426	validation_1-rmse:0.482452
# [26]	validation_0-rmse:0.387444	validation_1-rmse:0.481438
# [27]	validation_0-rmse:0.384304	validation_1-rmse:0.482399
# [28]	validation_0-rmse:0.381498	validation_1-rmse:0.483871
# [29]	validation_0-rmse:0.37936	validation_1-rmse:0.484865
# [30]	validation_0-rmse:0.378303	validation_1-rmse:0.484612
# [31]	validation_0-rmse:0.376512	validation_1-rmse:0.486255
# [32]	validation_0-rmse:0.375835	validation_1-rmse:0.486506
# [33]	validation_0-rmse:0.375173	validation_1-rmse:0.48645
# [34]	validation_0-rmse:0.374677	validation_1-rmse:0.486823
# [35]	validation_0-rmse:0.373187	validation_1-rmse:0.488492
# [36]	validation_0-rmse:0.372236	validation_1-rmse:0.489808
# Stopping. Best iteration:
# [26]	validation_0-rmse:0.387444	validation_1-rmse:0.481438
#
# [0]	validation_0-rmse:1.27779	validation_1-rmse:1.2755
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 10 rounds.
# [1]	validation_0-rmse:1.16209	validation_1-rmse:1.16321
# [2]	validation_0-rmse:1.05922	validation_1-rmse:1.0624
# [3]	validation_0-rmse:0.967875	validation_1-rmse:0.97397
# [4]	validation_0-rmse:0.886725	validation_1-rmse:0.897603
# [5]	validation_0-rmse:0.819808	validation_1-rmse:0.832561
# [6]	validation_0-rmse:0.75646	validation_1-rmse:0.773542
# [7]	validation_0-rmse:0.700666	validation_1-rmse:0.723401
# [8]	validation_0-rmse:0.655633	validation_1-rmse:0.681493
# [9]	validation_0-rmse:0.616377	validation_1-rmse:0.644669
# [10]	validation_0-rmse:0.57858	validation_1-rmse:0.612906
# [11]	validation_0-rmse:0.545906	validation_1-rmse:0.587249
# [12]	validation_0-rmse:0.521038	validation_1-rmse:0.565565
# [13]	validation_0-rmse:0.497086	validation_1-rmse:0.547546
# [14]	validation_0-rmse:0.479397	validation_1-rmse:0.532999
# [15]	validation_0-rmse:0.461378	validation_1-rmse:0.521771
# [16]	validation_0-rmse:0.448732	validation_1-rmse:0.511993
# [17]	validation_0-rmse:0.437976	validation_1-rmse:0.503801
# [18]	validation_0-rmse:0.426341	validation_1-rmse:0.498376
# [19]	validation_0-rmse:0.418964	validation_1-rmse:0.49313
# [20]	validation_0-rmse:0.410661	validation_1-rmse:0.490182
# [21]	validation_0-rmse:0.40367	validation_1-rmse:0.488524
# [22]	validation_0-rmse:0.3994	validation_1-rmse:0.485875
# [23]	validation_0-rmse:0.395914	validation_1-rmse:0.483844
# [24]	validation_0-rmse:0.393178	validation_1-rmse:0.482407
# [25]	validation_0-rmse:0.389426	validation_1-rmse:0.482452
# [26]	validation_0-rmse:0.387444	validation_1-rmse:0.481438
# [27]	validation_0-rmse:0.384304	validation_1-rmse:0.482399
# [28]	validation_0-rmse:0.381498	validation_1-rmse:0.483871
# [29]	validation_0-rmse:0.37936	validation_1-rmse:0.484865
# [30]	validation_0-rmse:0.378303	validation_1-rmse:0.484612
# [31]	validation_0-rmse:0.376512	validation_1-rmse:0.486255
# [32]	validation_0-rmse:0.375835	validation_1-rmse:0.486506
# [33]	validation_0-rmse:0.375173	validation_1-rmse:0.48645
# [34]	validation_0-rmse:0.374677	validation_1-rmse:0.486823
# [35]	validation_0-rmse:0.373187	validation_1-rmse:0.488492
# [36]	validation_0-rmse:0.372236	validation_1-rmse:0.489808
# Stopping. Best iteration:
# [26]	validation_0-rmse:0.387444	validation_1-rmse:0.481438
#
# [0]	validation_0-rmse:1.27772	validation_1-rmse:1.27551
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 10 rounds.
# [1]	validation_0-rmse:1.16199	validation_1-rmse:1.16317
# [2]	validation_0-rmse:1.05881	validation_1-rmse:1.06242
# [3]	validation_0-rmse:0.967389	validation_1-rmse:0.973841
# [4]	validation_0-rmse:0.886193	validation_1-rmse:0.897373
# [5]	validation_0-rmse:0.814368	validation_1-rmse:0.83138
# [6]	validation_0-rmse:0.751036	validation_1-rmse:0.773026
# [7]	validation_0-rmse:0.695643	validation_1-rmse:0.723056
# [8]	validation_0-rmse:0.650152	validation_1-rmse:0.680354
# [9]	validation_0-rmse:0.607234	validation_1-rmse:0.643859
# [10]	validation_0-rmse:0.57027	validation_1-rmse:0.613365
# [11]	validation_0-rmse:0.53817	validation_1-rmse:0.588315
# [12]	validation_0-rmse:0.510595	validation_1-rmse:0.56804
# [13]	validation_0-rmse:0.487126	validation_1-rmse:0.551426
# [14]	validation_0-rmse:0.468995	validation_1-rmse:0.537136
# [15]	validation_0-rmse:0.451807	validation_1-rmse:0.52644
# [16]	validation_0-rmse:0.439012	validation_1-rmse:0.516808
# [17]	validation_0-rmse:0.428191	validation_1-rmse:0.508839
# [18]	validation_0-rmse:0.417495	validation_1-rmse:0.503819
# [19]	validation_0-rmse:0.409946	validation_1-rmse:0.498733
# [20]	validation_0-rmse:0.402326	validation_1-rmse:0.495866
# [21]	validation_0-rmse:0.395821	validation_1-rmse:0.494388
# [22]	validation_0-rmse:0.390567	validation_1-rmse:0.492929
# [23]	validation_0-rmse:0.386116	validation_1-rmse:0.492419
# [24]	validation_0-rmse:0.382302	validation_1-rmse:0.492979
# [25]	validation_0-rmse:0.379017	validation_1-rmse:0.494024
# [26]	validation_0-rmse:0.376935	validation_1-rmse:0.493207
# [27]	validation_0-rmse:0.374321	validation_1-rmse:0.494787
# [28]	validation_0-rmse:0.3724	validation_1-rmse:0.495383
# [29]	validation_0-rmse:0.37079	validation_1-rmse:0.496176
# [30]	validation_0-rmse:0.369762	validation_1-rmse:0.495986
# [31]	validation_0-rmse:0.368439	validation_1-rmse:0.497541
# [32]	validation_0-rmse:0.367679	validation_1-rmse:0.497448
# [33]	validation_0-rmse:0.36679	validation_1-rmse:0.498415
# Stopping. Best iteration:
# [23]	validation_0-rmse:0.386116	validation_1-rmse:0.492419
#
# [0]	validation_0-rmse:1.27076	validation_1-rmse:1.27147
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 10 rounds.
# [1]	validation_0-rmse:1.15549	validation_1-rmse:1.1594
# [2]	validation_0-rmse:1.05283	validation_1-rmse:1.06059
# [3]	validation_0-rmse:0.961631	validation_1-rmse:0.973835
# [4]	validation_0-rmse:0.880841	validation_1-rmse:0.898205
# [5]	validation_0-rmse:0.809413	validation_1-rmse:0.831981
# [6]	validation_0-rmse:0.746377	validation_1-rmse:0.77479
# [7]	validation_0-rmse:0.691077	validation_1-rmse:0.725867
# [8]	validation_0-rmse:0.642676	validation_1-rmse:0.684028
# [9]	validation_0-rmse:0.600613	validation_1-rmse:0.648819
# [10]	validation_0-rmse:0.563957	validation_1-rmse:0.619197
# [11]	validation_0-rmse:0.532458	validation_1-rmse:0.594497
# [12]	validation_0-rmse:0.505449	validation_1-rmse:0.574249
# [13]	validation_0-rmse:0.482299	validation_1-rmse:0.557805
# [14]	validation_0-rmse:0.462728	validation_1-rmse:0.544289
# [15]	validation_0-rmse:0.445996	validation_1-rmse:0.533515
# [16]	validation_0-rmse:0.431875	validation_1-rmse:0.525113
# [17]	validation_0-rmse:0.41992	validation_1-rmse:0.518558
# [18]	validation_0-rmse:0.410029	validation_1-rmse:0.513311
# [19]	validation_0-rmse:0.401671	validation_1-rmse:0.509361
# [20]	validation_0-rmse:0.394591	validation_1-rmse:0.506861
# [21]	validation_0-rmse:0.388785	validation_1-rmse:0.504323
# [22]	validation_0-rmse:0.383912	validation_1-rmse:0.502952
# [23]	validation_0-rmse:0.379839	validation_1-rmse:0.50177
# [24]	validation_0-rmse:0.376511	validation_1-rmse:0.500724
# [25]	validation_0-rmse:0.37354	validation_1-rmse:0.500874
# [26]	validation_0-rmse:0.371051	validation_1-rmse:0.501421
# [27]	validation_0-rmse:0.369075	validation_1-rmse:0.501258
# [28]	validation_0-rmse:0.367397	validation_1-rmse:0.501269
# [29]	validation_0-rmse:0.366007	validation_1-rmse:0.501375
# [30]	validation_0-rmse:0.364778	validation_1-rmse:0.501825
# [31]	validation_0-rmse:0.363678	validation_1-rmse:0.502292
# [32]	validation_0-rmse:0.362652	validation_1-rmse:0.50405
# [33]	validation_0-rmse:0.361794	validation_1-rmse:0.505165
# [34]	validation_0-rmse:0.360826	validation_1-rmse:0.506995
# Stopping. Best iteration:
# [24]	validation_0-rmse:0.376511	validation_1-rmse:0.500724
#
# Parameters are finished for colsample_bytree. Best Iteration is 34
# Minimum Rmse : 0.469282, optimum parameter is 0.4 between [0.3, 0.5, 0.6, 0.8, 1]
# [0]	validation_0-rmse:1.33972	validation_1-rmse:1.33722
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 10 rounds.
# [1]	validation_0-rmse:1.27846	validation_1-rmse:1.27739
# [2]	validation_0-rmse:1.22064	validation_1-rmse:1.21993
# [3]	validation_0-rmse:1.16991	validation_1-rmse:1.169
# [4]	validation_0-rmse:1.12122	validation_1-rmse:1.12045
# [5]	validation_0-rmse:1.07611	validation_1-rmse:1.07623
# [6]	validation_0-rmse:1.02949	validation_1-rmse:1.03053
# [7]	validation_0-rmse:0.989035	validation_1-rmse:0.990096
# [8]	validation_0-rmse:0.950631	validation_1-rmse:0.952033
# [9]	validation_0-rmse:0.914247	validation_1-rmse:0.915937
# [10]	validation_0-rmse:0.88	validation_1-rmse:0.881617
# [11]	validation_0-rmse:0.844662	validation_1-rmse:0.848738
# [12]	validation_0-rmse:0.814806	validation_1-rmse:0.819615
# [13]	validation_0-rmse:0.787457	validation_1-rmse:0.792674
# [14]	validation_0-rmse:0.761771	validation_1-rmse:0.76798
# [15]	validation_0-rmse:0.733673	validation_1-rmse:0.74272
# [16]	validation_0-rmse:0.710421	validation_1-rmse:0.719843
# [17]	validation_0-rmse:0.688761	validation_1-rmse:0.698593
# [18]	validation_0-rmse:0.668624	validation_1-rmse:0.679102
# [19]	validation_0-rmse:0.652869	validation_1-rmse:0.664034
# [20]	validation_0-rmse:0.632106	validation_1-rmse:0.645989
# [21]	validation_0-rmse:0.615938	validation_1-rmse:0.630738
# [22]	validation_0-rmse:0.603342	validation_1-rmse:0.618911
# [23]	validation_0-rmse:0.589281	validation_1-rmse:0.605763
# [24]	validation_0-rmse:0.576294	validation_1-rmse:0.593668
# [25]	validation_0-rmse:0.561218	validation_1-rmse:0.581378
# [26]	validation_0-rmse:0.550229	validation_1-rmse:0.571153
# [27]	validation_0-rmse:0.539831	validation_1-rmse:0.561452
# [28]	validation_0-rmse:0.526819	validation_1-rmse:0.551755
# [29]	validation_0-rmse:0.515427	validation_1-rmse:0.54314
# [30]	validation_0-rmse:0.507303	validation_1-rmse:0.535795
# [31]	validation_0-rmse:0.499948	validation_1-rmse:0.529386
# [32]	validation_0-rmse:0.493096	validation_1-rmse:0.52326
# [33]	validation_0-rmse:0.486665	validation_1-rmse:0.51756
# [34]	validation_0-rmse:0.48115	validation_1-rmse:0.512694
# [35]	validation_0-rmse:0.472824	validation_1-rmse:0.507683
# [36]	validation_0-rmse:0.465813	validation_1-rmse:0.503211
# [37]	validation_0-rmse:0.461555	validation_1-rmse:0.499712
# [38]	validation_0-rmse:0.45743	validation_1-rmse:0.496177
# [39]	validation_0-rmse:0.453767	validation_1-rmse:0.493115
# [40]	validation_0-rmse:0.44779	validation_1-rmse:0.4899
# [41]	validation_0-rmse:0.445122	validation_1-rmse:0.487806
# [42]	validation_0-rmse:0.442222	validation_1-rmse:0.485512
# [43]	validation_0-rmse:0.437201	validation_1-rmse:0.483185
# [44]	validation_0-rmse:0.434953	validation_1-rmse:0.481495
# [45]	validation_0-rmse:0.432797	validation_1-rmse:0.479865
# [46]	validation_0-rmse:0.431084	validation_1-rmse:0.478621
# [47]	validation_0-rmse:0.42704	validation_1-rmse:0.477184
# [48]	validation_0-rmse:0.425349	validation_1-rmse:0.476016
# [49]	validation_0-rmse:0.42379	validation_1-rmse:0.474964
# [50]	validation_0-rmse:0.422407	validation_1-rmse:0.474027
# [51]	validation_0-rmse:0.421151	validation_1-rmse:0.4732
# [52]	validation_0-rmse:0.420026	validation_1-rmse:0.472473
# [53]	validation_0-rmse:0.418991	validation_1-rmse:0.471818
# [54]	validation_0-rmse:0.416059	validation_1-rmse:0.471313
# [55]	validation_0-rmse:0.415171	validation_1-rmse:0.470782
# [56]	validation_0-rmse:0.414406	validation_1-rmse:0.470359
# [57]	validation_0-rmse:0.413719	validation_1-rmse:0.469952
# [58]	validation_0-rmse:0.412991	validation_1-rmse:0.469534
# [59]	validation_0-rmse:0.41104	validation_1-rmse:0.469306
# [60]	validation_0-rmse:0.410517	validation_1-rmse:0.469034
# [61]	validation_0-rmse:0.409971	validation_1-rmse:0.468756
# [62]	validation_0-rmse:0.409546	validation_1-rmse:0.46859
# [63]	validation_0-rmse:0.408028	validation_1-rmse:0.468588
# [64]	validation_0-rmse:0.407612	validation_1-rmse:0.468428
# [65]	validation_0-rmse:0.407316	validation_1-rmse:0.468299
# [66]	validation_0-rmse:0.406998	validation_1-rmse:0.468167
# [67]	validation_0-rmse:0.405717	validation_1-rmse:0.468296
# [68]	validation_0-rmse:0.404558	validation_1-rmse:0.468469
# [69]	validation_0-rmse:0.404335	validation_1-rmse:0.46848
# [70]	validation_0-rmse:0.404092	validation_1-rmse:0.468413
# [71]	validation_0-rmse:0.40308	validation_1-rmse:0.468652
# [72]	validation_0-rmse:0.402163	validation_1-rmse:0.468917
# [73]	validation_0-rmse:0.400692	validation_1-rmse:0.469338
# [74]	validation_0-rmse:0.400496	validation_1-rmse:0.469359
# [75]	validation_0-rmse:0.399203	validation_1-rmse:0.469751
# [76]	validation_0-rmse:0.399055	validation_1-rmse:0.469729
# Stopping. Best iteration:
# [66]	validation_0-rmse:0.406998	validation_1-rmse:0.468167
#
# Parameters are finished for learning_rate. Best Iteration is 66
# Minimum Rmse : 0.468167, optimum parameter is 0.05 between [0.05]
